# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from selenium.webdriver.common.by import By 
from selenium.webdriver.chrome.options import Options
import random
import time

# ===============================
# AYARLAR
# ===============================
BASLANGIC_SAYFASI = 13
BITIS_SAYFASI = 18

BASE_URL = "https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa="
CIKTI_DOSYA = "bornova_13_19_sayfa_ilanlar.csv"


# ===============================
# SAYFA LİNKLERİNİ TOPLA
# ===============================
def ilan_linklerini_topla(driver, basla, bitir):
    linkler = set()

    for sayfa in range(basla, bitir + 1):
        url = BASE_URL + str(sayfa)
        print(f"\n➡ Sayfa {sayfa} çekiliyor: {url}")

        driver.get(url)
        time.sleep(random.uniform(4, 7))

        soup = BeautifulSoup(driver.page_source, "html.parser")
        cardlar = soup.find_all("a", href=True)

        sayfa_sayisi = 0
        for c in cardlar:
            if c["href"].startswith("/ilan/"):
                tam_link = "https://www.emlakjet.com" + c["href"]
                if tam_link not in linkler:
                    linkler.add(tam_link)
                    sayfa_sayisi += 1

        print(f"   -> Bu sayfada {sayfa_sayisi} yeni ilan bulundu | Toplam: {len(linkler)}")

    print(f"\n🎯 SONUÇ: {len(linkler)} adet benzersiz ilan linki toplandı.")
    return list(linkler)


# ===============================
# İLAN DETAY SAYFASINI ÇEK
# ===============================
def ilan_detaylarini_cek(driver, url):
    detaylar = {"URL": url}

    try:
        driver.get(url)
        time.sleep(random.uniform(4, 7))

        soup = BeautifulSoup(driver.page_source, "html.parser")

        # FİYAT
        try:
            fiyat = soup.find("span", {"class": "styles_price__6wmxk"})
            detaylar["Fiyat"] = fiyat.text.strip() if fiyat else "N/A"
        except:
            detaylar["Fiyat"] = "N/A"

        # BAŞLIK
        try:
            baslik = soup.find("h1", class_="ej-title")
            detaylar["Baslik"] = baslik.text.strip() if baslik else "N/A"
        except:
            detaylar["Baslik"] = "N/A"

        # ADRES (İl - İlçe - Mahalle)
        try:
            adres = soup.find("span", class_="styles_location__HguIg")
            if adres:
                parcalar = adres.text.split("-")
                detaylar["İl"] = parcalar[0].strip() if len(parcalar) > 0 else "N/A"
                detaylar["İlçe"] = parcalar[1].strip() if len(parcalar) > 1 else "N/A"
                detaylar["Mahalle"] = parcalar[2].strip() if len(parcalar) > 2 else "N/A"
            else:
                detaylar["Mahalle"] = "N/A"
        except:
            detaylar["Mahalle"] = "N/A"

        # ÖZELLİKLER
        try:
            ozellik_div = soup.find("div", class_="styles_inner__qKPCB")
            if ozellik_div:
                for li in ozellik_div.find_all("li"):
                    spans = li.find_all("span")
                    if len(spans) >= 2:
                        key = spans[0].text.strip()
                        value = spans[-1].text.strip()
                        detaylar[key] = value
        except:
            pass

        # AÇIKLAMA
        try:
            aciklama_div = soup.find("div", class_="styles_wrapper__hycT_")
            detaylar["Aciklama"] = aciklama_div.text.strip().replace("\n", " ") if aciklama_div else "N/A"
        except:
            detaylar["Aciklama"] = "N/A"

    except Exception as e:
        print(f"   !!! HATA: {url} sayfası çekilemedi -> {e}")

    return detaylar


# ===============================
# ANA ÇALIŞMA BLOĞU
# ===============================
if __name__ == "__main__":
    print("🚀 Chrome başlatılıyor...")

    options = Options()
    options.add_argument("--headless")
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_experimental_option("excludeSwitches", ["enable-automation"])
    options.add_experimental_option("useAutomationExtension", False)

    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=options)
    driver.execute_script("Object.defineProperty(navigator, 'webdriver', {get: () => undefined})")

    # 1) LİNKLERİ TOPLA
    ilan_linkleri = ilan_linklerini_topla(driver, BASLANGIC_SAYFASI, BITIS_SAYFASI)

    # 2) DETAYLARI ÇEK
    tum_ilan_verileri = []
    print("\n🔍 İlan detayları çekiliyor...\n")

    for i, link in enumerate(ilan_linkleri):
        print(f"[{i+1}/{len(ilan_linkleri)}] {link}")
        detay = ilan_detaylarini_cek(driver, link)
        tum_ilan_verileri.append(detay)
        time.sleep(random.uniform(3, 6))

    # 3) CSV KAYDET
    if tum_ilan_verileri:
        df = pd.DataFrame(tum_ilan_verileri)
        df.to_csv(CIKTI_DOSYA, index=False, encoding="utf-8-sig")
        print(f"\n💾 VERİ KAYDEDİLDİ → {CIKTI_DOSYA}")
    else:
        print("❌ Veri yok, CSV oluşturulmadı.")

    driver.quit()
    print("🚪 Tarayıcı kapatıldı.")
# Out:
# 🚀 Chrome başlatılıyor...
#
# ➡ Sayfa 13 çekiliyor: https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa=13
#    -> Bu sayfada 30 yeni ilan bulundu | Toplam: 30
#
# ➡ Sayfa 14 çekiliyor: https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa=14
#    -> Bu sayfada 30 yeni ilan bulundu | Toplam: 60
#
# ➡ Sayfa 15 çekiliyor: https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa=15
#    -> Bu sayfada 30 yeni ilan bulundu | Toplam: 90
#
# ➡ Sayfa 16 çekiliyor: https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa=16
#    -> Bu sayfada 30 yeni ilan bulundu | Toplam: 120
#
# ➡ Sayfa 17 çekiliyor: https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa=17
#    -> Bu sayfada 30 yeni ilan bulundu | Toplam: 150
#
# ➡ Sayfa 18 çekiliyor: https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa=18
#    -> Bu sayfada 30 yeni ilan bulundu | Toplam: 180
#
# 🎯 SONUÇ: 180 adet benzersiz ilan linki toplandı.
#
# 🔍 İlan detayları çekiliyor...
#
# [1/180] https://www.emlakjet.com/ilan/bornova-yakakoy-de-satilik-loft-tas-ev-17516826
# [2/180] https://www.emlakjet.com/ilan/sertac-gayrimenkulden-mustakil-ev-17492830
# [3/180] https://www.emlakjet.com/ilan/camdibi-tuval-yapi-barbaros-mahallesi-satilik-21-daire-18053041
# [4/180] https://www.emlakjet.com/ilan/yesilova-da-emsallerinden-muhtesem-31-17621525
# [5/180] https://www.emlakjet.com/ilan/krediye-uygun-bornova-merekeze-yurume-mesafesinde-18052240
# [6/180] https://www.emlakjet.com/ilan/kazancli-is-firsati-satilik-tam-donanimli-kiracili-ruhsatli-anaokulu-17666684
# [7/180] https://www.emlakjet.com/ilan/kw-cobans-tan-bornova-altindag-da-satilik-21-mustakil-daireterasli-kat-bahceli-17629876
# [8/180] https://www.emlakjet.com/ilan/bornova-site-icinde-havuzlu-satilik-31-17789797
# [9/180] https://www.emlakjet.com/ilan/bornova-erzene-mahallesi-31-satilik-daire-17862283
# [10/180] https://www.emlakjet.com/ilan/bornova-asik-veysel-rekreasyon-alani-karsisi-dogalgazli-31-17808505
# [11/180] https://www.emlakjet.com/ilan/bornova-altindag-serintepe-de-satilik-3-katli-mustakil-bina-17540519
# [12/180] https://www.emlakjet.com/ilan/ikon-live-130-m2-satilik-31-havuz-cephe-daire-17699865
# [13/180] https://www.emlakjet.com/ilan/ikon-live-130-m2-satilik-31-havuz-cephe-daire-18050138
# [14/180] https://www.emlakjet.com/ilan/tuval-yapi-21-satilik-daire-17729994
# [15/180] https://www.emlakjet.com/ilan/bornova-yakakoy-21-ozel-yapim-sifir-tek-tapu-mustakil-ev-17991067
# [16/180] https://www.emlakjet.com/ilan/camdibi-nde-3-katli-mustakil-ev-tapulari-ayri-kat-mulkiyetli-17930965
# [17/180] https://www.emlakjet.com/ilan/bornova-meydan-cadde-uzeri-tadilatli-bos-satilik-31-daire-17488136
# [18/180] https://www.emlakjet.com/ilan/anka-gayrimenkul-den-bornova-nin-merkezinde-satilik-daireler-17860052
# [19/180] https://www.emlakjet.com/ilan/bornova-veranova-sitesi-nde-21-satilik-bahceli-dubleks-daire-17552660
# [20/180] https://www.emlakjet.com/ilan/ergene-mah-asik-veysel-yakini-550-sokak-ta-21-satilik-daire-18007952
# [21/180] https://www.emlakjet.com/ilan/folkart-life-bornova-21-satilik-daire-17900877
# [22/180] https://www.emlakjet.com/ilan/ataturk-mahallesinde-tripleks-luks-villa-18010420
# [23/180] https://www.emlakjet.com/ilan/ataturk-mahallesinde-220-m2-41-ultra-luks-satilik-villa-18046669
# [24/180] https://www.emlakjet.com/ilan/altindag-kosukavak-mahallesinde-satilik-daire-17529751
# [25/180] https://www.emlakjet.com/ilan/bornova-doganlar-da-31-satilik-luks-cati-dubleks-daire-17757628
# [26/180] https://www.emlakjet.com/ilan/bornova-dap-yapi-da-krediye-uygun-kiracili-daire-17840906
# [27/180] https://www.emlakjet.com/ilan/pinarbasi-nda-sifir-dogalgazli-21-satilik-daire-18022215
# [28/180] https://www.emlakjet.com/ilan/ikon-tower-da-esyali-satilik-11-daire-17985243
# [29/180] https://www.emlakjet.com/ilan/gho-life-dan-bornova-goldiva-familya-da-21-firsat-daire-17934768
# [30/180] https://www.emlakjet.com/ilan/sertac-gayrimenkulden-uc-arti-bir-17470214
# [31/180] https://www.emlakjet.com/ilan/form-bornova-yakini-onag-yasam-evleri-sitesinde-31-luks-daire-17984444
# [32/180] https://www.emlakjet.com/ilan/bornova-k-park-ta-sifir-ultralux-satilik-31-otoparkli-daire-17976282
# [33/180] https://www.emlakjet.com/ilan/folkart-incity-de-havuz-manzarali-full-esyali-11-satilik-daire-17867274
# [34/180] https://www.emlakjet.com/ilan/ferah-nezih-daire-17613094
# [35/180] https://www.emlakjet.com/ilan/kw-cobans-dan-bornova-camdibi-nde-4-kat-imarli-160-m-uygun-fiyatli-mustakil-ev-yenileme-firsati-17603110
# [36/180] https://www.emlakjet.com/ilan/bornova-avcilar-prestij-te-31-satilik-bos-havuz-manzarali-daire-17852118
# [37/180] https://www.emlakjet.com/ilan/yakakoy-de-350-m2-arsa-icerisinde-21-mustakil-17539473
# [38/180] https://www.emlakjet.com/ilan/0-99-dan-baslayan-kredi-imkani-41-ebeveyn-banyolu-satilik-daire-17739167
# [39/180] https://www.emlakjet.com/ilan/bornova-tuval-yapida-buyuk-tip-31-satilik-daire-17933576
# [40/180] https://www.emlakjet.com/ilan/sade-den-bornova-kizilay-mahallesin-satilik-mustakil-ev-ve-arsa-17835945
# [41/180] https://www.emlakjet.com/ilan/ataturk-mahallesinde-5-katli-komple-bina-17755113
# [42/180] https://www.emlakjet.com/ilan/folkart-time-10-park-cepheli-kiracisiz-satilik-daire-17565600
# [43/180] https://www.emlakjet.com/ilan/real-center-bornova-neva-suits-de-genis-terasli-ultra-luks-11-17774555
# [44/180] https://www.emlakjet.com/ilan/kizilay-mahallesinde-satilik-31-dubleks-daire-17894229
# [45/180] https://www.emlakjet.com/ilan/bornova-kizilay-mahallesi-nde-satilik-21-bahceli-ev-17949194
# [46/180] https://www.emlakjet.com/ilan/forum-bornova-villa-17953729
# [47/180] https://www.emlakjet.com/ilan/bornova-kucukpark-in-kalbinde-satilik-daire-17752950
# [48/180] https://www.emlakjet.com/ilan/super-lux-ebevyn-banyolu-giyinme-odali-fuul-yapili-asansorlu-18029300
# [49/180] https://www.emlakjet.com/ilan/bornova-dap-yapi-da-krediye-uygun-kiracili-daire-17841109
# [50/180] https://www.emlakjet.com/ilan/point-bornova-residance-korfez-manzarali-satilik-buyuk-tip-31-17871040
# [51/180] https://www.emlakjet.com/ilan/otuzbes-ten-kelepir-satilik-3-katli-binabornova-camkule-de-17633434
# [52/180] https://www.emlakjet.com/ilan/bornova-yatay-mimari-konsept-site-havuz-cephe-bahceli-11-daire-18000623
# [53/180] https://www.emlakjet.com/ilan/inonu-mahallesinde-luks-21-satilik-merkezi-konumda-daire-17903286
# [54/180] https://www.emlakjet.com/ilan/camdibi-tuval-yapi-satilik-11-daire-17730137
# [55/180] https://www.emlakjet.com/ilan/sertac-gayrimenkulden-bir-artibir-iki-artibir-daireler-17515978
# [56/180] https://www.emlakjet.com/ilan/bornova-altindag-da-komple-satilik-bina-17778688
# [57/180] https://www.emlakjet.com/ilan/bornova-kucuk-park-merkezde-isyerine-uygun-satilik-31-daire-17570800
# [58/180] https://www.emlakjet.com/ilan/bornova-evka-4te-komple-yenilenmis-site-ici-satilik-daire-18014101
# [59/180] https://www.emlakjet.com/ilan/viven-tower-projesinde-21-deniz-manzarali-yatirima-uygun-firsat-17903373
# [60/180] https://www.emlakjet.com/ilan/zafer-mahallesinde-satilik-21-daire-17790656
# [61/180] https://www.emlakjet.com/ilan/blackstone-dan-acil-satilik-firsat-daire-17661489
# [62/180] https://www.emlakjet.com/ilan/11-bornova-varyant-tower-residance-luks-esyali-satilik-daire-17914861
# [63/180] https://www.emlakjet.com/ilan/sertac-gayrimenkulden-17515859
# [64/180] https://www.emlakjet.com/ilan/e-b-bornova-dap-izmir-2-kisilik-full-esyali-10-satilik-daire-17965972
# [65/180] https://www.emlakjet.com/ilan/bornova-gediz-caddesinde-dogalgazli-asansorlu-31-daire-17677581
# [66/180] https://www.emlakjet.com/ilan/bornova-kazimdirik-te-satilik-31-daire-17925390
# [67/180] https://www.emlakjet.com/ilan/turpa-saygindan-nest-camdibi-konutlarinda-17877318
# [68/180] https://www.emlakjet.com/ilan/camdibinde-3-katli-kiracili-satilik-mustakil-ev-17554801
# [69/180] https://www.emlakjet.com/ilan/bornova-mevlana-mahallesi-satilik-21-kapali-mutfak-daire-18043841
# [70/180] https://www.emlakjet.com/ilan/tek-gayrimenkulden-31-135m2-temiz-bakimli-daire-17926870
# [71/180] https://www.emlakjet.com/ilan/evka-3-de-satilik-kose-konumlu-bahceli-ferah-41-tripleks-villa-17946437
# [72/180] https://www.emlakjet.com/ilan/bornova-isikkent-de-31-genis-ferah-daire-17876629
# [73/180] https://www.emlakjet.com/ilan/park-yasam-bornova-yasar-uni-yani-satilik-31-havuz-cephe-daire-17996137
# [74/180] https://www.emlakjet.com/ilan/bornova-mevlana-mahallesi-nde-4-katli-komple-satilik-bina-17740449
# [75/180] https://www.emlakjet.com/ilan/tek-gayrimenkulden21-merkezi-konumda-satilik-daire-17886365
# [76/180] https://www.emlakjet.com/ilan/bornova-mevlana-da-11-satilik-daire-18033279
# [77/180] https://www.emlakjet.com/ilan/point-bornova-da-21-korfez-manzarali-luks-satilik-daire-17624573
# [78/180] https://www.emlakjet.com/ilan/21-kapali-mutfak-dogalgazli-full-tadilatli-satilik-daire-17894115
# [79/180] https://www.emlakjet.com/ilan/bornova-da-31-satilik-daire-18006502
# [80/180] https://www.emlakjet.com/ilan/nest-camdibi-bornova-satilik-31-daire-17793531
# [81/180] https://www.emlakjet.com/ilan/sertac-gayrimenkulden-120mkare-iki-artibir-kapali-mutfak-ful-kiredi-kullanilabilir-17896193
# [82/180] https://www.emlakjet.com/ilan/bornova-ataturk-mah-deniz-manzarali-3-katli-satilik-bina-18020276
# [83/180] https://www.emlakjet.com/ilan/31-kapali-mutfak-ferah-satilik-daire-17894143
# [84/180] https://www.emlakjet.com/ilan/bornova-ataturk-mah-2-katli-mustakil-ev-17653161
# [85/180] https://www.emlakjet.com/ilan/otuzbes-ten-acil-satilik-3-katli-komple-bina-kelepir-fiyat-yuksek-kira-getirisi-17640574
# [86/180] https://www.emlakjet.com/ilan/bornova-yasar-uni-yani-park-yasam-bornova-satilik-daire-18054434
# [87/180] https://www.emlakjet.com/ilan/a24-site-emlak-bornova-kazimdirik-avcilar-prestij-sitesinde-satilik-31-17450633
# [88/180] https://www.emlakjet.com/ilan/yesilova-da-21-zemin-kat-dogalgazli-sifir-daire-17697797
# [89/180] https://www.emlakjet.com/ilan/bornova-merkezde-cadde-ustu-yesil-alan-manzarali-satilik-21-17871074
# [90/180] https://www.emlakjet.com/ilan/ataturk-mah-de-giris-kat-10-satilik-daire-yatirim-firsati-17849987
# [91/180] https://www.emlakjet.com/ilan/bornova-ergene-mahallesi-31-satilik-dubleks-daire-17638544
# [92/180] https://www.emlakjet.com/ilan/bornova-mevlana-mahallesi-satilik-daire-17677563
# [93/180] https://www.emlakjet.com/ilan/universite-yakini-havuzlu-sitede-satilik-11-lux-daire-18016333
# [94/180] https://www.emlakjet.com/ilan/park-yasam-bornova-11-balkonlu-satilik-firsat-daire-18054436
# [95/180] https://www.emlakjet.com/ilan/modda-bayraklida-korfez-manzarali-satilik-21-daire-17833174
# [96/180] https://www.emlakjet.com/ilan/ataturk-mahhalesinde-kapali-mutfak-31-100m2-daire-18054629
# [97/180] https://www.emlakjet.com/ilan/epa-emlak-bornova-yesillikler-icinde-manzara-31-satilik-daire-17975927
# [98/180] https://www.emlakjet.com/ilan/gho-life-gayrimenkul-den-folkart-life-balkonlu-31-satilik-daire-17874654
# [99/180] https://www.emlakjet.com/ilan/my-gayrimenkul-den-luks-11-satilik-daireler-17930934
# [100/180] https://www.emlakjet.com/ilan/bornova-izev-moon-projesinde-31-satilik-daire-18033520
# [101/180] https://www.emlakjet.com/ilan/bornova-doganlar-satilik-11-17621486
# [102/180] https://www.emlakjet.com/ilan/bornova-kazimdirik-te-subat-ayinda-teslim-satilik-21-daire-18042055
# [103/180] https://www.emlakjet.com/ilan/bornova-camdibi-mahallesinde-satlik-21-daire-18055613
# [104/180] https://www.emlakjet.com/ilan/passa-nova-sitesinde-satilik-11-firsat-daire-18005790
# [105/180] https://www.emlakjet.com/ilan/satilik-mustekil-uckatli-ev-17650069
# [106/180] https://www.emlakjet.com/ilan/cumba-gayrimenkulden-satilik-mustakil-ev-17833169
# [107/180] https://www.emlakjet.com/ilan/tuval-yapi-satilik-21-daire-17730083
# [108/180] https://www.emlakjet.com/ilan/garden-bornova-sitesi-nde-satilik-11-havuz-cepheli-daire-17519926
# [109/180] https://www.emlakjet.com/ilan/bornova-camdibinde-satilik-mustalik-ev-17730044
# [110/180] https://www.emlakjet.com/ilan/bornova-erzene-de-satilik-21-firsat-daire-17973414
# [111/180] https://www.emlakjet.com/ilan/bornova-evka-3-un-en-nezih-ve-luks-binasinda-satilik-31-daire-17746111
# [112/180] https://www.emlakjet.com/ilan/bornova-merkez-ergene-mahallesinde-21-satilik-daire-17770082
# [113/180] https://www.emlakjet.com/ilan/dap-yapi-da-acil-satilik-55-m-deniz-manzarali-11-daire-17840946
# [114/180] https://www.emlakjet.com/ilan/bornova-kucukpark-yeni-bina-11-satilik-daire-17715784
# [115/180] https://www.emlakjet.com/ilan/artenew-den-bornova-ataturk-de-arakat-satilik-dogalgazli-sifir-yapili-full-esyali-satilik-daire-17637216
# [116/180] https://www.emlakjet.com/ilan/cb-360-folkart-life-21-havuz-cephe-balkonlu-daire-17933586
# [117/180] https://www.emlakjet.com/ilan/bornova-mevlana-mahallesi-ege-uni-yakini-11-satilik-daire-17707854
# [118/180] https://www.emlakjet.com/ilan/kw-cobans-dan-kucukpark-ta-kacmaz-ebeveyn-banyolu-balkonlu-otoparkli-daire-17476587
# [119/180] https://www.emlakjet.com/ilan/kucukpark-meydan-konut-isletme-kullanim-uygun-1-kat-satilik-17871073
# [120/180] https://www.emlakjet.com/ilan/sertac-gayrimenkul-den-17737565
# [121/180] https://www.emlakjet.com/ilan/soli-bornova-folkart-incity-deniz-havuz-cephe-satilik-21-17876564
# [122/180] https://www.emlakjet.com/ilan/izmir-bornova-kazimdirik-te-satilik-31-ara-kat-sifir-daire-17857151
# [123/180] https://www.emlakjet.com/ilan/41-satilik-lux-akilli-villa-17894165
# [124/180] https://www.emlakjet.com/ilan/park-yasam-bornova-terasli-11-satilik-daire-18041069
# [125/180] https://www.emlakjet.com/ilan/bornova-mevlana-sitesi-nde-merkezi-konum-satilik-genis-31-daire-17857197
# [126/180] https://www.emlakjet.com/ilan/sertac-gayrimenkulden-kizilay-mah-3artibir-120metre-kare-bahcekati-17768497
# [127/180] https://www.emlakjet.com/ilan/satilik-masrafsiz-dubleks-luks-daire-bornova-ataturk-mah-17624608
# [128/180] https://www.emlakjet.com/ilan/otuzbes-ten-bornova-erzen-de-luks-2-1-yeni-bina-asansorlu-17535630
# [129/180] https://www.emlakjet.com/ilan/turyap-tan-bornova-merkezde-satilik-bos-ara-kat-21-daire-17984439
# [130/180] https://www.emlakjet.com/ilan/turyap-tan-genc-binada-bahce-kati-satilik-31-daire-17518538
# [131/180] https://www.emlakjet.com/ilan/izmir-bornova-evka-3-te-satilik-daire-18002573
# [132/180] https://www.emlakjet.com/ilan/31-satilik-ferah-daire-18039568
# [133/180] https://www.emlakjet.com/ilan/gurpinar-gayrimekulden-31-temiz-bakimli-daire-18016838
# [134/180] https://www.emlakjet.com/ilan/bornova-evka-3-aegean-forest-luks-konfor-ve-guvenli-yasam-17911656
# [135/180] https://www.emlakjet.com/ilan/bornova-camdibi-buzcular-sitesi-nde-satilik-31-daire-17658736
# [136/180] https://www.emlakjet.com/ilan/buraxtan-ataturk-mh-yavuzcad-uzerinde-21-satilik-daire-17598334
# [137/180] https://www.emlakjet.com/ilan/erdemay-emlaktan-satilik11-inonu-mahallesinde-mustakil-18022845
# [138/180] https://www.emlakjet.com/ilan/ege-univ-hasta-metro-yakini-yatirimlik-satilik-21-daire-17756502
# [139/180] https://www.emlakjet.com/ilan/bornova-nin-tam-merkezinde-dogalgazli-esyali-satilik-31-daire-17920107
# [140/180] https://www.emlakjet.com/ilan/forum-bornova-ya-yurume-mesafesinde-41-tripleks-mustakil-villa-17857134
# [141/180] https://www.emlakjet.com/ilan/bornova-kemalpasa-mahallesinde-11-satilik-daire-17608429
# [142/180] https://www.emlakjet.com/ilan/turyap-tan-bornova-evka-3-te-41-satilik-daire-17800543
# [143/180] https://www.emlakjet.com/ilan/bornova-evka-4-tadilatli-satilik-21-18053063
# [144/180] https://www.emlakjet.com/ilan/yigit-gayrimenkul-den-bornova-ergene-de-satilik-11-daire-17624520
# [145/180] https://www.emlakjet.com/ilan/camdibinde-merkezi-konumda-31-kapali-mutfakterasli-daire-17945578
# [146/180] https://www.emlakjet.com/ilan/inonu-mahallesinde-3-cepheli-135-m2-satilik-daire-18001323
# [147/180] https://www.emlakjet.com/ilan/kw-cobans-tan-fevzi-cakmak-caddesi-uzeri-ata-apartmani-nda-100m-yenilenmis-daire-17777748
# [148/180] https://www.emlakjet.com/ilan/21-islek-cadde-uzerinde-acil-satilik-17993045
# [149/180] https://www.emlakjet.com/ilan/inonu-mahallesinde-satilik-21-luks-merkezi-konumda-daire-17894147
# [150/180] https://www.emlakjet.com/ilan/bornova-kizilay-mahallesi-nde-genc-binada-satilik-daire-kiracisiz-17452002
# [151/180] https://www.emlakjet.com/ilan/kw-coban-s-tan-bornova-meric-mahallesi-nde-2-katli-musatakil-bina-teras-17629809
# [152/180] https://www.emlakjet.com/ilan/bornova-ataturk-mah-homeros-vadisi-manzarali-71-satilik-villa-18050055
# [153/180] https://www.emlakjet.com/ilan/bornova-da-21-satilik-luks-daire-17947049
# [154/180] https://www.emlakjet.com/ilan/park-yasam-bornova-bahce-kati-terasli-satilik-11-daire-18041068
# [155/180] https://www.emlakjet.com/ilan/bornovada-9-daire-1-dukkan-kelepir-satilik-17911497
# [156/180] https://www.emlakjet.com/ilan/folkart-life-balkonlu-havuz-cephe-11-guclu-yatirim-firsati-17779272
# [157/180] https://www.emlakjet.com/ilan/izmir-bornova-zafer-de-satilik-31-daire-17983332
# [158/180] https://www.emlakjet.com/ilan/31-kapali-mutfak-satilik-daire-bornova-inonu-mahlesinde-17976285
# [159/180] https://www.emlakjet.com/ilan/bornova-dap-izmir-kule-deniz-manzarali-esyali-11-satilik-daire-17816294
# [160/180] https://www.emlakjet.com/ilan/bornova-merkeze-yurume-mesafesinde-11-satilik-daire-17621431
# [161/180] https://www.emlakjet.com/ilan/bornova-ataturk-mah-ana-cadde-uzeri-satilik-21-tadilatli-daire-17927702
# [162/180] https://www.emlakjet.com/ilan/keyifli-bir-yasam-sunan-erzene-mh-21-satilik-genis-daire-17855072
# [163/180] https://www.emlakjet.com/ilan/bornova-ataturk-mahallesinde-deniz-manzarali-31-satilik-daire-17907849
# [164/180] https://www.emlakjet.com/ilan/bornova-mevlana-da-sifir-21-3-kat-kapali-otoparkli-modern-ferah-ve-konforlu-daire-17574549
# [165/180] https://www.emlakjet.com/ilan/21-satilik-kose-daire-17528964
# [166/180] https://www.emlakjet.com/ilan/bornova-da-11-esyali-satilik-luks-daire-17774062
# [167/180] https://www.emlakjet.com/ilan/yesilova-mahallesi-atuf-bey-sitesinde-satilik-daire-17950467
# [168/180] https://www.emlakjet.com/ilan/fb-gayrimenkul-den-yaka-da-mustakil-tapulu-bahceli-kagir-ev-17986583
# [169/180] https://www.emlakjet.com/ilan/evka-3te-merkezi-konumda-satilik-daire-17889746
# [170/180] https://www.emlakjet.com/ilan/evkad-erdemay-emlaktan-acik-mutfak-guney-arakat-satilik-tadilatli-17777238
# [171/180] https://www.emlakjet.com/ilan/0-99-dan-baslayan-firsat-sifir-31-satilik-daire-17739165
# [172/180] https://www.emlakjet.com/ilan/bornova-kucukpark-yakini-31-asansorlu-daire-17696118
# [173/180] https://www.emlakjet.com/ilan/hs-den-kacirilmayacak-firsat-17467282
# [174/180] https://www.emlakjet.com/ilan/bornova-mevlana-mahallesinde-ful-tadilatli-satilik-daire-18043852
# [175/180] https://www.emlakjet.com/ilan/nehir-emlak-insaat-tan-satilik-mevlana-mah-11-45-m2-daire-17628493
# [176/180] https://www.emlakjet.com/ilan/bornova-35-pesin-kalani-vade-deniz-manz-31-sifir-daireler-17975722
# [177/180] https://www.emlakjet.com/ilan/bornova-kizilay-mah-sifir-tadilatli-11-satilik-daire-17864737
# [178/180] https://www.emlakjet.com/ilan/zafer-caddesi-uzeri-ara-kat-31-masrafsiz-daire-17507008
# [179/180] https://www.emlakjet.com/ilan/11-satilik-daire-ege-universitesi-kampus-yakini-18049882
# [180/180] https://www.emlakjet.com/ilan/izmir-evka-3-izban-14km-yakakoy-satilik-mustakil-ev-17697628
#
# 💾 VERİ KAYDEDİLDİ → bornova_13_19_sayfa_ilanlar.csv
# 🚪 Tarayıcı kapatıldı.

# %%
df=pd.read_csv("bornova_13_19_sayfa_ilanlar.csv")
df["İlan Numarası"].nunique()
# Out:
# 180

# %%
df.to_csv("C:\\Users\\ACER\\Desktop\\MlVERİLERİ", index=False, encoding="utf-8-sig")

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Aysima\\Desktop\\3.sınıf\\veriler3.csv")
