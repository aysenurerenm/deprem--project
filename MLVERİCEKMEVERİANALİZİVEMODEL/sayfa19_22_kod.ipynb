# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from selenium.webdriver.common.by import By 
from selenium.webdriver.chrome.options import Options
import random
import time

# ===============================
# AYARLAR
# ===============================
BASLANGIC_SAYFASI = 19
BITIS_SAYFASI = 22

BASE_URL = "https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa="
CIKTI_DOSYA = "bornova_13_19_sayfa_ilanlar.csv"


# ===============================
# SAYFA LİNKLERİNİ TOPLA
# ===============================
def ilan_linklerini_topla(driver, basla, bitir):
    linkler = set()

    for sayfa in range(basla, bitir + 1):
        url = BASE_URL + str(sayfa)
        print(f"\n➡ Sayfa {sayfa} çekiliyor: {url}")

        driver.get(url)
        time.sleep(random.uniform(4, 7))

        soup = BeautifulSoup(driver.page_source, "html.parser")
        cardlar = soup.find_all("a", href=True)

        sayfa_sayisi = 0
        for c in cardlar:
            if c["href"].startswith("/ilan/"):
                tam_link = "https://www.emlakjet.com" + c["href"]
                if tam_link not in linkler:
                    linkler.add(tam_link)
                    sayfa_sayisi += 1

        print(f"   -> Bu sayfada {sayfa_sayisi} yeni ilan bulundu | Toplam: {len(linkler)}")

    print(f"\n🎯 SONUÇ: {len(linkler)} adet benzersiz ilan linki toplandı.")
    return list(linkler)


# ===============================
# İLAN DETAY SAYFASINI ÇEK
# ===============================
def ilan_detaylarini_cek(driver, url):
    detaylar = {"URL": url}

    try:
        driver.get(url)
        time.sleep(random.uniform(4, 7))

        soup = BeautifulSoup(driver.page_source, "html.parser")

        # FİYAT
        try:
            fiyat = soup.find("span", {"class": "styles_price__6wmxk"})
            detaylar["Fiyat"] = fiyat.text.strip() if fiyat else "N/A"
        except:
            detaylar["Fiyat"] = "N/A"

        # BAŞLIK
        try:
            baslik = soup.find("h1", class_="ej-title")
            detaylar["Baslik"] = baslik.text.strip() if baslik else "N/A"
        except:
            detaylar["Baslik"] = "N/A"

        # ADRES (İl - İlçe - Mahalle)
        try:
            adres = soup.find("span", class_="styles_location__HguIg")
            if adres:
                parcalar = adres.text.split("-")
                detaylar["İl"] = parcalar[0].strip() if len(parcalar) > 0 else "N/A"
                detaylar["İlçe"] = parcalar[1].strip() if len(parcalar) > 1 else "N/A"
                detaylar["Mahalle"] = parcalar[2].strip() if len(parcalar) > 2 else "N/A"
            else:
                detaylar["Mahalle"] = "N/A"
        except:
            detaylar["Mahalle"] = "N/A"

        # ÖZELLİKLER
        try:
            ozellik_div = soup.find("div", class_="styles_inner__qKPCB")
            if ozellik_div:
                for li in ozellik_div.find_all("li"):
                    spans = li.find_all("span")
                    if len(spans) >= 2:
                        key = spans[0].text.strip()
                        value = spans[-1].text.strip()
                        detaylar[key] = value
        except:
            pass

        # AÇIKLAMA
        try:
            aciklama_div = soup.find("div", class_="styles_wrapper__hycT_")
            detaylar["Aciklama"] = aciklama_div.text.strip().replace("\n", " ") if aciklama_div else "N/A"
        except:
            detaylar["Aciklama"] = "N/A"

    except Exception as e:
        print(f"   !!! HATA: {url} sayfası çekilemedi -> {e}")

    return detaylar


# ===============================
# ANA ÇALIŞMA BLOĞU
# ===============================
if __name__ == "__main__":
    print("🚀 Chrome başlatılıyor...")

    options = Options()
    options.add_argument("--headless")
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_experimental_option("excludeSwitches", ["enable-automation"])
    options.add_experimental_option("useAutomationExtension", False)

    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=options)
    driver.execute_script("Object.defineProperty(navigator, 'webdriver', {get: () => undefined})")

    # 1) LİNKLERİ TOPLA
    ilan_linkleri = ilan_linklerini_topla(driver, BASLANGIC_SAYFASI, BITIS_SAYFASI)

    # 2) DETAYLARI ÇEK
    tum_ilan_verileri = []
    print("\n🔍 İlan detayları çekiliyor...\n")

    for i, link in enumerate(ilan_linkleri):
        print(f"[{i+1}/{len(ilan_linkleri)}] {link}")
        detay = ilan_detaylarini_cek(driver, link)
        tum_ilan_verileri.append(detay)
        time.sleep(random.uniform(3, 6))

    # 3) CSV KAYDET
    if tum_ilan_verileri:
        df = pd.DataFrame(tum_ilan_verileri)
        df.to_csv(CIKTI_DOSYA, index=False, encoding="utf-8-sig")
        print(f"\n💾 VERİ KAYDEDİLDİ → {CIKTI_DOSYA}")
    else:
        print("❌ Veri yok, CSV oluşturulmadı.")

    driver.quit()
    print("🚪 Tarayıcı kapatıldı.")
# Out:
# 🚀 Chrome başlatılıyor...
#
# ➡ Sayfa 19 çekiliyor: https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa=19
#    -> Bu sayfada 30 yeni ilan bulundu | Toplam: 30
#
# ➡ Sayfa 20 çekiliyor: https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa=20
#    -> Bu sayfada 30 yeni ilan bulundu | Toplam: 60
#
# ➡ Sayfa 21 çekiliyor: https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa=21
#    -> Bu sayfada 30 yeni ilan bulundu | Toplam: 90
#
# ➡ Sayfa 22 çekiliyor: https://www.emlakjet.com/satilik-konut/izmir-bornova/?sayfa=22
#    -> Bu sayfada 13 yeni ilan bulundu | Toplam: 103
#
# 🎯 SONUÇ: 103 adet benzersiz ilan linki toplandı.
#
# 🔍 İlan detayları çekiliyor...
#
# [1/103] https://www.emlakjet.com/ilan/izmir-bornova-yesilova-da-satilik-krediye-uygun-31-16961573
# [2/103] https://www.emlakjet.com/ilan/bornova-merkez-de-satilik-41-daire-8895925
# [3/103] https://www.emlakjet.com/ilan/bornova-yakakoyde-satilik-mustakil-ev-17437005
# [4/103] https://www.emlakjet.com/ilan/kw-cobans-tan-kosukavak-ta-genis-ve-konforlu-yeni-full-tadilatli-daire-17310656
# [5/103] https://www.emlakjet.com/ilan/bornova-kizilayda-satilik-124m2-31-kapali-mutfakli-otoparkli-ara-kat-daire-15939326
# [6/103] https://www.emlakjet.com/ilan/nest-camdibinde-31-satilik-genis-daire-tip12-17060996
# [7/103] https://www.emlakjet.com/ilan/bornova-kizilayda-satilik-120m2-31-kapali-mutfakli-otoparkli-yeni-tadilatli-ara-kat-daire-15987132
# [8/103] https://www.emlakjet.com/ilan/ege-unuvertesine-yurume-mesafesinde-mustakil-tadinda-31-15787961
# [9/103] https://www.emlakjet.com/ilan/bornova-pinarbasi-kemalpasa-mah-de-satilik-31-daire-16936764
# [10/103] https://www.emlakjet.com/ilan/bornova-pinarbasi-nda-31-arakat-satilik-daire-16881774
# [11/103] https://www.emlakjet.com/ilan/erzene-mahallesi-nde-satilik-31-genis-ferah-daire-15920860
# [12/103] https://www.emlakjet.com/ilan/bornova-ataturk-te-21-satilik-daire-17426203
# [13/103] https://www.emlakjet.com/ilan/bornova-evka-3-mahallesinde-42-terasli-dubleks-satilik-daire-17366585
# [14/103] https://www.emlakjet.com/ilan/bornova-doganlar-da-21-satilik-luks-daire-17344212
# [15/103] https://www.emlakjet.com/ilan/izmir-bornova-cicekli-koy-firsat-daire-21-17280017
# [16/103] https://www.emlakjet.com/ilan/bornova-evka-3-te-neva-suits-de-satilik-11-daire-15189406
# [17/103] https://www.emlakjet.com/ilan/bornova-yaka-koyde-satilik-dubleks-tas-villa-16582834
# [18/103] https://www.emlakjet.com/ilan/bornova-viven-tower-da-11-satilik-daire-16781945
# [19/103] https://www.emlakjet.com/ilan/kw-cobans-dan-merkezi-konumda-4-katli-3-5-daireli-1-dukkan-ve-depolu-yatirimlik-komple-bina-17238980
# [20/103] https://www.emlakjet.com/ilan/bornova-kucukpark-ta-ici-sifir-yapili-asansorlu-satilik-21-daire-17166515
# [21/103] https://www.emlakjet.com/ilan/camdibi-nde-tek-tapu-3-katli-bina-17141432
# [22/103] https://www.emlakjet.com/ilan/bornova-kizilayda-satilik-124m2-31-kapali-mutfakli-otoparkli-ust-kat-daire-15929202
# [23/103] https://www.emlakjet.com/ilan/komple-satilik-121-m2-3-daire-sanayi-elektrikli-1-dukkan-tapulari-ayri-15772962
# [24/103] https://www.emlakjet.com/ilan/camdibi-nde-satilik-4-kat-11-daire-16999155
# [25/103] https://www.emlakjet.com/ilan/4-cepheli-asansorlu-cadde-uzeri-satilik-luks-daire-16841056
# [26/103] https://www.emlakjet.com/ilan/bornova-camdibinde-21-satilik-daire-16968179
# [27/103] https://www.emlakjet.com/ilan/izmir-sarnic-ta-satilik-2858-m2-arazi-icinde-3-katli-mustakil-ev-16684161
# [28/103] https://www.emlakjet.com/ilan/izmir-bornova-yildirim-beyazit-cad-uzerinde-4-kata-imarli-mustakil-bina-14004999
# [29/103] https://www.emlakjet.com/ilan/izmir-bornova-altindag-120-m2-mustakil-ev-50-m2-arsa-hediye-17428580
# [30/103] https://www.emlakjet.com/ilan/bornova-evka-3-de-satilik-41-luks-villa-12105711
# [31/103] https://www.emlakjet.com/ilan/bornova-pinarbasi-nda-site-icerisinde-satilik-31-havuzlu-daire-bahce-dubleks-17402894
# [32/103] https://www.emlakjet.com/ilan/doganlarda-satilik-21-luks-dogalgazli-cati-dublexi-14691842
# [33/103] https://www.emlakjet.com/ilan/bornova-evka-3te-satilik-11-via-zone-projesi-dairesi-16874807
# [34/103] https://www.emlakjet.com/ilan/izmir-bornova-altindag-satilik-daire-katta-31-yatirimlik-firsat-17429108
# [35/103] https://www.emlakjet.com/ilan/izmir-bornova-altindag-kemalpasa-caddesi-yakini-satilik-mustakil-ev-15797560
# [36/103] https://www.emlakjet.com/ilan/izmir-bornova-deniz-manzarali-havuzlu-esyali-luks-satilik-rezidans-daire-13916451
# [37/103] https://www.emlakjet.com/ilan/kun-emlakdan-21-dogalgazli-90-m2-daire-17211146
# [38/103] https://www.emlakjet.com/ilan/kosukavak-mah-de-dogalgazli-arakat-satilik-21-daire-17364950
# [39/103] https://www.emlakjet.com/ilan/bornova-pinarbasi-satilik-31-daire-site-havuzlu-site-icerisinde-cati-dubleks-17402868
# [40/103] https://www.emlakjet.com/ilan/bornova-yakakoy-1131-m2-icinde-300-m2-41-doga-manzarali-villa-17297386
# [41/103] https://www.emlakjet.com/ilan/bornova-doganlar-da-21-satilik-luks-daire-17072630
# [42/103] https://www.emlakjet.com/ilan/fb-gayrimenkul-den-cicekli-koy-de-satilik-bahceli-mustakil-ev-16681511
# [43/103] https://www.emlakjet.com/ilan/bornovanin-tam-merkezinde-yatirimlik-sifir-21-kapali-mutfakli-15787958
# [44/103] https://www.emlakjet.com/ilan/bornova-ataturk-mahallesinde-yatirimlik-kiracili-bina-16480748
# [45/103] https://www.emlakjet.com/ilan/bornova-pinarbasi-nda-luks-site-icerisinde-satilik-11-daire-17405167
# [46/103] https://www.emlakjet.com/ilan/bornova-camdibi-nde-yatirimlik-komple-satilik-bina-16924402
# [47/103] https://www.emlakjet.com/ilan/kiracili-ara-kat-bir-yillik-21-17273523
# [48/103] https://www.emlakjet.com/ilan/artenew-den-10-yuksek-giris-2-yillik-mus-girsli-satilik-daire-16657716
# [49/103] https://www.emlakjet.com/ilan/bornova-inonu-mah-5-katli-satilik-bina-15397430
# [50/103] https://www.emlakjet.com/ilan/inonu-de-komple-satilik-5-katli-bina-15035891
# [51/103] https://www.emlakjet.com/ilan/bornova-doganlar-da-satilik-komple-bina-14971524
# [52/103] https://www.emlakjet.com/ilan/camdibi-altindag-caddesine-yakin-komple-satilik-mustakil-bina-17011370
# [53/103] https://www.emlakjet.com/ilan/bornova-ataturk-mahallesinde-satilik-uc-katli-bina-ve-isyeri-16860933
# [54/103] https://www.emlakjet.com/ilan/fb-gayrimenkul-den-yaka-da-mustakil-tapulu-bahceli-kagir-ev-17418835
# [55/103] https://www.emlakjet.com/ilan/11-satilik-daire-16007737
# [56/103] https://www.emlakjet.com/ilan/doganlarin-en-guzel-yerinde-mustakil-dublex-daire-17127026
# [57/103] https://www.emlakjet.com/ilan/yesilova-mahallesinde-satilik-bina-17145522
# [58/103] https://www.emlakjet.com/ilan/yesilova-mahallesinde-satilik-31-daire-17152918
# [59/103] https://www.emlakjet.com/ilan/31-doganlar-mh-bornova-16401761
# [60/103] https://www.emlakjet.com/ilan/passa-nova-bornova-satilik-21-daire-17068644
# [61/103] https://www.emlakjet.com/ilan/satilik-mustakil-ev-camdibi-izmir-bornova-17031595
# [62/103] https://www.emlakjet.com/ilan/doganlar-da-satilik-3-katli-bina-14577378
# [63/103] https://www.emlakjet.com/ilan/ataturk-mahallesinde-balkonlu-satilik-21-17344460
# [64/103] https://www.emlakjet.com/ilan/bornova-mevlana-da-41satilik-cati-dubleks-daire-15009075
# [65/103] https://www.emlakjet.com/ilan/izmir-bornova-inonu-ergene-mah-31-deniz-manzarali-genis-daire-16836898
# [66/103] https://www.emlakjet.com/ilan/artenew-den-21-dogalgazli-100-m2-3-cepheli-satilik-16219728
# [67/103] https://www.emlakjet.com/ilan/bornova-viven-tower-da-10-satilik-daire-16924685
# [68/103] https://www.emlakjet.com/ilan/sertac-gayrimenkulden-iki-arti-bir-ara-kat-17402431
# [69/103] https://www.emlakjet.com/ilan/altindag-da-kelepir-2-katli-bina-16882564
# [70/103] https://www.emlakjet.com/ilan/birlik-mahallesinde-satilik-bina-17044250
# [71/103] https://www.emlakjet.com/ilan/merkezi-konumda-31-acik-mutfak-sifir-dublex-daire-16982558
# [72/103] https://www.emlakjet.com/ilan/forum-da-sadece-16-villalik-sitede-ozel-havuzlu-580-m2-8130748
# [73/103] https://www.emlakjet.com/ilan/bornova-da-satiliik-21-satilik-luks-daireler-10835337
# [74/103] https://www.emlakjet.com/ilan/bornova-ergene-mah-kucukpark-yakini-satilik-yeni-21-daire-16925465
# [75/103] https://www.emlakjet.com/ilan/bornova-gayrimenkulden-satilik-41-17013029
# [76/103] https://www.emlakjet.com/ilan/dairemiz-isikkentte-yeni-yapilan-sitelerin-altindadir-15408485
# [77/103] https://www.emlakjet.com/ilan/trio-life-satilik-21-daire-17282107
# [78/103] https://www.emlakjet.com/ilan/bornova-yesilovada-satilik-21-kose-daire-16897188
# [79/103] https://www.emlakjet.com/ilan/kizilay-mahallesinde-21-bahceli-kose-konumda-giris-kat-daire-17226106
# [80/103] https://www.emlakjet.com/ilan/fb-gayrimenkul-den-cicekli-koy-de-satilik-bahceli-mustakil-ev-16720252
# [81/103] https://www.emlakjet.com/ilan/soli-forum-bornova-yakini-havuzlu-villa-15782170
# [82/103] https://www.emlakjet.com/ilan/camdibi-kentsel-donusum-alaninda-2-katli-komple-satilik-mustakil-17321153
# [83/103] https://www.emlakjet.com/ilan/ismet-sezgin-okuluna-700-m-mesafede-ara-kat-31-16819884
# [84/103] https://www.emlakjet.com/ilan/kw-cobans-dan-erzene-mahallesi-nde-yatirimlik-komple-kose-bina-17155510
# [85/103] https://www.emlakjet.com/ilan/emlak-buraya-dan-dap-kulelerde-satilik-studyo-daire-17341153
# [86/103] https://www.emlakjet.com/ilan/ataturk-ismet-sezgin-okuluna-500-m-mesafede-16806928
# [87/103] https://www.emlakjet.com/ilan/bornova-zafer-de-satilik-mustakil-ev-ve-arsasi-15308491
# [88/103] https://www.emlakjet.com/ilan/bornova-ataturk-mahallesinde-2-katli-terasli-satilik-mustakil-ev-15821248
# [89/103] https://www.emlakjet.com/ilan/camdibi-altindag-caddesine-yakin-satilik-mustakil-ev-17046550
# [90/103] https://www.emlakjet.com/ilan/satilik-daire-camdibinde-bornova-31-17008780
# [91/103] https://www.emlakjet.com/ilan/bornova-ataturk-te-satilik-41-luks-tribleks-villalar-15952896
# [92/103] https://www.emlakjet.com/ilan/inonu-de-satilik-21-bahce-kati-daire-14971544
# [93/103] https://www.emlakjet.com/ilan/artenew-den-21-mustakil-bahceli-cadde-uzeri-satilik-16219291
# [94/103] https://www.emlakjet.com/ilan/ege-univ-hastane-metro-yakini-yatirima-uygun-10-yasinda-21-daire-14971357
# [95/103] https://www.emlakjet.com/ilan/ciritoglu-konutlari-firsat-31-satilik-16156802
# [96/103] https://www.emlakjet.com/ilan/suna-tabakci-dan-izmir-bornova-5-katli-satilik-bina-15729816
# [97/103] https://www.emlakjet.com/ilan/bornova-da-31-satilik-luks-daire-15233931
# [98/103] https://www.emlakjet.com/ilan/dogalgazli-31-kapali-mutfakli-firsat-satilik-daire-16638460
# [99/103] https://www.emlakjet.com/ilan/bornova-doganlar-da-21-satilik-luks-daire-14971540
# [100/103] https://www.emlakjet.com/ilan/avcilar-effect-te-son-katta-yanyana-satilik-2-adet-11-daire-16400378
# [101/103] https://www.emlakjet.com/ilan/kosukavak-mahallesinde-satilik-bina-17336636
# [102/103] https://www.emlakjet.com/ilan/bornova-gurpinar-mahallesinde-21-satilik-sifir-daire-17399534
# [103/103] https://www.emlakjet.com/ilan/viven-tower-da-yatirim-firsati-11-daire-17348222
#
# 💾 VERİ KAYDEDİLDİ → bornova_13_19_sayfa_ilanlar.csv
# 🚪 Tarayıcı kapatıldı.

# %%
df1=pd.read_csv("bornova_13_19_sayfa_ilanlar.csv")
df1.to_csv("C:\\Users\\Acer\\Desktop\\veriler3.csv", index=False, encoding="utf-8-sig")

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\ACER\\Desktop\\MlVERİLERİ\\veriler4.csv")
df["İlan Numarası"].nunique()
# Out:
# 103
